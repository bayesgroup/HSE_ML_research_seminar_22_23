# %% [markdown]
# # Panoptic Neural Fields

# %% [markdown]
# ### Installation

# %%
# !git clone https://github.com/xheon/panoptic-reconstruction.git
# %cd panoptic-reconstruction
# Out:
# Cloning into 'panoptic-reconstruction'...
# remote: Enumerating objects: 507, done.
# remote: Counting objects: 100% (130/130), done.
# remote: Compressing objects: 100% (56/56), done.
# remote: Total 507 (delta 92), reused 77 (delta 74), pack-reused 377
# Receiving objects: 100% (507/507), 14.35 MiB | 24.70 MiB/s, done.
# Resolving deltas: 100% (211/211), done.
# /content/panoptic-reconstruction

# %%
# %cd /content
# Out:
# /content

# %%
# !git clone https://github.com/cocodataset/cocoapi.git
# Out:
# Cloning into 'cocoapi'...
# remote: Enumerating objects: 975, done.
# remote: Total 975 (delta 0), reused 0 (delta 0), pack-reused 975
# Receiving objects: 100% (975/975), 11.72 MiB | 30.63 MiB/s, done.
# Resolving deltas: 100% (576/576), done.

# %%
# %cd cocoapi/PythonAPI
# !python setup.py build_ext install
# Out:
# /content/cocoapi/PythonAPI
# running build_ext
# cythoning pycocotools/_mask.pyx to pycocotools/_mask.c
# /usr/local/lib/python3.8/dist-packages/Cython/Compiler/Main.py:369: FutureWarning: Cython directive 'language_level' not set, using 2 for now (Py2). This will change in a later release! File: /content/cocoapi/PythonAPI/pycocotools/_mask.pyx
#   tree = Parsing.p_module(s, pxd, full_module_name)
# building 'pycocotools._mask' extension
# creating build
# creating build/common
# creating build/temp.linux-x86_64-3.8
# creating build/temp.linux-x86_64-3.8/pycocotools
# ...

# %%
# %cd /content
# !git clone https://github.com/mcordts/cityscapesScripts.git
# %cd cityscapesScripts/
# !python setup.py build_ext install
# Out:
# /content
# Cloning into 'cityscapesScripts'...
# remote: Enumerating objects: 630, done.
# remote: Counting objects: 100% (203/203), done.
# remote: Compressing objects: 100% (53/53), done.
# remote: Total 630 (delta 172), reused 153 (delta 150), pack-reused 427
# Receiving objects: 100% (630/630), 792.25 KiB | 12.58 MiB/s, done.
# Resolving deltas: 100% (358/358), done.
# /content/cityscapesScripts
# /usr/local/lib/python3.8/dist-packages/setuptools/dist.py:697: UserWarning: Usage of dash-separated 'description-file' will not be supported in future versions. Please use the underscore name 'description_file' instead
#   warnings.warn(
# running build_ext
# running install
# running bdist_egg
# running egg_info
# creating cityscapesScripts.egg-info
# writing cityscapesScripts.egg-info/PKG-INFO
# writing dependency_links to cityscapesScripts.egg-info/dependency_links.txt
# writing entry points to cityscapesScripts.egg-info/entry_points.txt
# ...

# %%
# %cd /content
# !git clone https://github.com/NVIDIA/apex.git
# %cd apex
# !python setup.py install --cuda_ext --cpp_ext
# Out:
# /content
# Cloning into 'apex'...
# remote: Enumerating objects: 10773, done.
# remote: Counting objects: 100% (6/6), done.
# remote: Compressing objects: 100% (6/6), done.
# remote: Total 10773 (delta 1), reused 1 (delta 0), pack-reused 10767
# Receiving objects: 100% (10773/10773), 15.18 MiB | 5.50 MiB/s, done.
# Resolving deltas: 100% (7467/7467), done.
# /content/apex
#
#
# torch.__version__  = 1.13.1+cu116
#
#
#
# Compiling cuda extensions with
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2022 NVIDIA Corporation
# Built on Tue_Mar__8_18:18:20_PST_2022
# Cuda compilation tools, release 11.6, V11.6.124
# Build cuda_11.6.r11.6/compiler.31057947_0
# from /usr/local/cuda/bin
#
# running install
# running bdist_egg
# running egg_info
# creating apex.egg-info
# writing apex.egg-info/PKG-INFO
# writing dependency_links to apex.egg-info/dependency_links.txt
# writing requirements to apex.egg-info/requires.txt
# writing top-level names to apex.egg-info/top_level.txt
# ...

# %%
# %cd /content
# !git clone https://github.com/facebookresearch/maskrcnn-benchmark.git
# %cd maskrcnn-benchmark
# !python setup.py build develop
# Out:
# /content
# Cloning into 'maskrcnn-benchmark'...
# remote: Enumerating objects: 1932, done.
# remote: Total 1932 (delta 0), reused 0 (delta 0), pack-reused 1932
# Receiving objects: 100% (1932/1932), 6.67 MiB | 28.82 MiB/s, done.
# Resolving deltas: 100% (1203/1203), done.
# /content/maskrcnn-benchmark
# running build
# running build_py
# creating build
# creating build/lib.linux-x86_64-3.8
# creating build/lib.linux-x86_64-3.8/maskrcnn_benchmark
# copying maskrcnn_benchmark/__init__.py -> build/lib.linux-x86_64-3.8/maskrcnn_benchmark
# creating build/lib.linux-x86_64-3.8/maskrcnn_benchmark/utils
# copying maskrcnn_benchmark/utils/model_serialization.py -> build/lib.linux-x86_64-3.8/maskrcnn_benchmark/utils
# copying maskrcnn_benchmark/utils/registry.py -> build/lib.linux-x86_64-3.8/maskrcnn_benchmark/utils
# copying maskrcnn_benchmark/utils/__init__.py -> build/lib.linux-x86_64-3.8/maskrcnn_benchmark/utils
# ...

# %%
# !pip install -U git+https://github.com/NVIDIA/MinkowskiEngine -v --no-deps --install-option="--force_cuda"
# Out:
# WARNING: Disabling all use of wheels due to the use of --build-option / --global-option / --install-option.
# Using pip 22.0.4 from /usr/local/lib/python3.8/dist-packages/pip (python 3.8)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Cloning https://github.com/NVIDIA/MinkowskiEngine to /tmp/pip-req-build-jugi5344
#   Running command git version
#   git version 2.25.1
#   Running command git clone --filter=blob:none https://github.com/NVIDIA/MinkowskiEngine /tmp/pip-req-build-jugi5344
#   Cloning into '/tmp/pip-req-build-jugi5344'...
#   Running command git rev-parse HEAD
#   405b39cb7e68c2ec1b4ac8c4b4ca9fa6fcfcb2fc
#   Resolved https://github.com/NVIDIA/MinkowskiEngine to commit 405b39cb7e68c2ec1b4ac8c4b4ca9fa6fcfcb2fc
#   Running command python setup.py egg_info
#   WARNING: Skipping MinkowskiEngine as it is not installed.
#   --------------------------------
#   | CUDA compilation set         |
# ...

# %%
# %cd /content/panoptic-reconstruction/lib/csrc
# !python setup.py install
# Out:
# /content/panoptic-reconstruction/lib/csrc
# running install
# running bdist_egg
# running egg_info
# creating extension.egg-info
# writing extension.egg-info/PKG-INFO
# writing dependency_links to extension.egg-info/dependency_links.txt
# writing top-level names to extension.egg-info/top_level.txt
# writing manifest file 'extension.egg-info/SOURCES.txt'
# /usr/local/lib/python3.8/dist-packages/torch/utils/cpp_extension.py:476: UserWarning: Attempted to use ninja as the BuildExtension backend but we could not find ninja.. Falling back to using the slow distutils backend.
#   warnings.warn(msg.format('we could not find ninja.'))
# reading manifest file 'extension.egg-info/SOURCES.txt'
# writing manifest file 'extension.egg-info/SOURCES.txt'
# installing library code to build/bdist.linux-x86_64/egg
# running install_lib
# running build_ext
# building 'lib_extension._C' extension
# creating build
# creating build/temp.linux-x86_64-3.8
# creating build/temp.linux-x86_64-3.8/content
# ...

# %%
# !wget https://kaldir.vc.in.tum.de/panoptic_reconstruction/panoptic-front3d.pth
# Out:
# --2023-02-15 10:49:09--  https://kaldir.vc.in.tum.de/panoptic_reconstruction/panoptic-front3d.pth
# Resolving kaldir.vc.in.tum.de (kaldir.vc.in.tum.de)... 131.159.98.128
# Connecting to kaldir.vc.in.tum.de (kaldir.vc.in.tum.de)|131.159.98.128|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 110984871 (106M)
# Saving to: ‘panoptic-front3d.pth’
#
# panoptic-front3d.pt 100%[===================>] 105.84M  13.8MB/s    in 30s
#
# 2023-02-15 10:49:40 (3.50 MB/s) - ‘panoptic-front3d.pth’ saved [110984871/110984871]

# %%
# !wget https://kaldir.vc.in.tum.de/panoptic_reconstruction/panoptic-front3d-mask_depth_r18.pth
# Out:
# --2023-02-15 10:50:03--  https://kaldir.vc.in.tum.de/panoptic_reconstruction/panoptic-front3d-mask_depth_r18.pth
# Resolving kaldir.vc.in.tum.de (kaldir.vc.in.tum.de)... 131.159.98.128
# Connecting to kaldir.vc.in.tum.de (kaldir.vc.in.tum.de)|131.159.98.128|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 71991807 (69M)
# Saving to: ‘panoptic-front3d-mask_depth_r18.pth’
#
# panoptic-front3d-ma 100%[===================>]  68.66M  19.2MB/s    in 3.6s
#
# 2023-02-15 10:50:07 (19.2 MB/s) - ‘panoptic-front3d-mask_depth_r18.pth’ saved [71991807/71991807]

# %%
# !pwd
# Out:
# /content/panoptic-reconstruction/lib/csrc

# %%
# !mv panoptic-front3d.pth /content/panoptic-reconstruction/resources/panoptic-front3d.pth

# %%
# !mv panoptic-front3d-mask_depth_r18.pth /content/panoptic-reconstruction/resources/panoptic-front3d-mask_depth_r18.pth

# %%
# %cd /content/panoptic-reconstruction
# Out:
# /content/panoptic-reconstruction

# %%
# !mkdir out

# %%
# !pwd
# Out:
# /content/panoptic-reconstruction

# %%
# !mkdir input
# !cp data/front3d-sample/rgb_0007.png input/rgb_0007.png

# %% [markdown]
# ### Example

# %%
# !python tools/test_net_single_image.py -i input/gb_0007.png -o data/

# %%
import numpy as np

# %%
npz = np.load('data/gb_0007/geometry.npz')

# %%
npz

# %%
restoration = npz['data']

# %%
# !pip install git+https://github.com/xheon/PyMarchingCubes.git git+https://github.com/xheon/PyMarchingCubes.git
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Cloning https://github.com/xheon/PyMarchingCubes.git to /tmp/pip-req-build-qw5hk7eq
#   Running command git clone --filter=blob:none --quiet https://github.com/xheon/PyMarchingCubes.git /tmp/pip-req-build-qw5hk7eq
#   Resolved https://github.com/xheon/PyMarchingCubes.git to commit a6ad0388187b50dc62032a39359463d811af6768
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for PyMarchingCubes: filename=PyMarchingCubes-0.0.3-cp38-cp38-linux_x86_64.whl size=1417023 sha256=db436b813d77afd69d4bd87961e68f1a0da9bd63a1b8266656c8235f0c83ea8f
#   Stored in directory: /tmp/pip-ephem-wheel-cache-8xgnhdr1/wheels/9f/1b/3f/bd2a63622ca9406ceb0241b72a49813ccc94e9c186e4c81e2d
# Successfully built PyMarchingCubes
# ...

# %%
# !pip install git+https://github.com/jamesbowman/openexrpython.git
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Cloning https://github.com/jamesbowman/openexrpython.git to /tmp/pip-req-build-92xpd2ho
#   Running command git clone --filter=blob:none --quiet https://github.com/jamesbowman/openexrpython.git /tmp/pip-req-build-92xpd2ho
#   Resolved https://github.com/jamesbowman/openexrpython.git to commit 91ec8a81a0bad7b30170c66769464cc7ab44ce4b
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for OpenEXR: filename=OpenEXR-1.3.2-cp38-cp38-linux_x86_64.whl size=276914 sha256=720a7aaace762354ece4e2155d27ae933c7452baeb98c62f8130ebc4c77f7c5d
#   Stored in directory: /tmp/pip-ephem-wheel-cache-2pj5t25q/wheels/7f/6c/a2/07dbe12d14dbad285babaa4af64b09b510d97ee4622903c9a0
# Successfully built OpenEXR
# ...
#   Attempting uninstall: OpenEXR
#     Found existing installation: OpenEXR 1.3.9
#     Uninstalling OpenEXR-1.3.9:
#       Successfully uninstalled OpenEXR-1.3.9
# ...

# %%
# !pip install plyfile
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
import pyexr

f = pyexr.open("data/gb_0007/depth.exr")

# %%
arr = f.get() # H, W, 1

# %%
arr = np.repeat(arr, 3, axis=-1).to

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(arr[:, :, 0])

# %%
npz = np.load("data/gb_0007/geometry.npz")

# %%
data = npz['data']

# %%
data.shape
# Out:
# (256, 256, 256)

# %%
plt.imshow(data[:, :, 100])

# %%
plt.imshow(data[:, 125, :])

# %%
from IPython.display import clear_output

# %%
import time

# %%
fig, axs = plt.subplots(1, 7, figsize=(50, 20))
for idx, i in enumerate(map(int, np.linspace(0, 120, 7))):
    axs[idx].imshow(data[:, :, i])

# %%
fig, axs = plt.subplots(1, 7, figsize=(50, 20))
for idx, i in enumerate(map(int, np.linspace(130, 100, 7))):
    axs[idx].imshow(data[:, i, :])

# %%
fig, axs = plt.subplots(1, 7, figsize=(50, 20))
for idx, i in enumerate(map(int, np.linspace(105, 190, 7))):
    axs[idx].imshow(data[i, :, :])

# %% [markdown]
# ### Projections

# %%
w = np.load("data/gb_0007/weighting.npz")

# %%
data_w = w['data']

# %%
fig, axs = plt.subplots(1, 7, figsize=(50, 20))
for idx, i in enumerate(map(int, np.linspace(120, 140, 7))):
    axs[idx].imshow(np.flip(data_w[:, :, i].T))

# %%
fig, axs = plt.subplots(1, 7, figsize=(50, 20))
for idx, i in enumerate(map(int, np.linspace(105, 135, 7))):
    axs[idx].imshow(data_w[:, i, :])

# %%
fig, axs = plt.subplots(1, 7, figsize=(50, 20))
for idx, i in enumerate(map(int, np.linspace(120, 145, 7))):
    axs[idx].imshow(data_w[i, :, :].T)

# %%
fru = np.load('data/frustum_mask.npz')

# %%
fru['mask'].shape
# Out:
# (256, 256, 256)
